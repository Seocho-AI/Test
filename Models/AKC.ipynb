# %%
import pandas as pd
import numpy as np

# %%
breeds_desc=pd.read_csv('akcdata-master/data/akc-data-latest.csv', index_col=0)

# %%
breeds_desc.describe()
# Out:
#        min_height  max_height  min_weight  max_weight  min_expectancy  \
# count  277.000000  277.000000  275.000000  275.000000      274.000000
# mean    44.225801   52.720588   17.888858   27.291416       11.306569
# std     14.238298   15.885454   12.290600   19.061416        1.817949
# min     12.700000   17.780000    0.000000    0.000000        0.000000
# 25%     33.020000   38.100000    8.164663   12.927383       10.000000
# 50%     45.085000   53.340000   15.875733   24.947580       12.000000
# 75%     55.880000   66.040000   22.679619   34.019428       12.000000
# max     76.200000   88.900000   68.038855  108.862169       16.000000
#
#        max_expectancy  grooming_frequency_value  shedding_value  \
# count      274.000000                270.000000      257.000000
# mean        13.832117                  0.425926        0.529183
# std          2.016668                  0.198306        0.189068
# min          0.000000                  0.200000        0.200000
# ...

# %%
breeds_desc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 277 entries, Affenpinscher to Yorkshire Terrier
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   description                  277 non-null    object
#  1   temperament                  276 non-null    object
#  2   popularity                   198 non-null    object
#  3   min_height                   277 non-null    float64
#  4   max_height                   277 non-null    float64
#  5   min_weight                   275 non-null    float64
#  6   max_weight                   275 non-null    float64
#  7   min_expectancy               274 non-null    float64
#  8   max_expectancy               274 non-null    float64
#  9   group                        277 non-null    object
#  10  grooming_frequency_value     270 non-null    float64
#  11  grooming_frequency_category  270 non-null    object
# ...

# %%
breeds_desc.head()
# Out:
#                                                         description  \
# Affenpinscher     The Affen’s apish look has been described many...
# Afghan Hound      The Afghan Hound is an ancient breed, his whol...
# Airedale Terrier  The Airedale Terrier is the largest of all ter...
# Akita             Akitas are burly, heavy-boned spitz-type dogs ...
# Alaskan Malamute  The Alaskan Malamute stands 23 to 25 inches at...
#
#                                                 temperament popularity  \
# Affenpinscher           Confident, Famously Funny, Fearless        148
# Afghan Hound      Dignified, Profoundly Loyal, Aristocratic        113
# Airedale Terrier               Friendly, Clever, Courageous         60
# Akita               Courageous, Dignified, Profoundly Loyal         47
# Alaskan Malamute               Affectionate, Loyal, Playful         58
#
#                   min_height  max_height  min_weight  max_weight  \
# ...
