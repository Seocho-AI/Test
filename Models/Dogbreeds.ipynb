# %%
import pandas as pd
import numpy as np

# %%
breeds=pd.read_csv('dogbreeds-master/breeds.csv', index_col=0)

# %%
breeds.describe()
# Out:
#        a_adaptability  a1_adapts_well_to_apartment_living  \
# count      349.000000                          349.000000
# mean         3.065903                            3.057307
# std          0.529270                            1.501775
# min          2.000000                            1.000000
# 25%          3.000000                            2.000000
# 50%          3.000000                            3.000000
# 75%          3.000000                            4.000000
# max          4.000000                            5.000000
#
#        a2_good_for_novice_owners  a3_sensitivity_level  \
# count                 349.000000            349.000000
# mean                    2.882521              3.742120
# std                     1.179547              0.842122
# min                     1.000000              2.000000
# 25%                     2.000000              3.000000
# 50%                     3.000000              4.000000
# ...

# %%
breeds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 349 entries, Afador to Yorkshire Terrier
# Data columns (total 36 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   url                                 349 non-null    object
#  1   a_adaptability                      349 non-null    int64
#  2   a1_adapts_well_to_apartment_living  349 non-null    int64
#  3   a2_good_for_novice_owners           349 non-null    int64
#  4   a3_sensitivity_level                349 non-null    int64
#  5   a4_tolerates_being_alone            349 non-null    int64
#  6   a5_tolerates_cold_weather           349 non-null    int64
#  7   a6_tolerates_hot_weather            349 non-null    int64
#  8   b_all_around_friendliness           349 non-null    int64
#  9   b1_affectionate_with_family         349 non-null    int64
#  10  b2_incredibly_kid_friendly_dogs     349 non-null    int64
# ...

# %%
breeds.head()
# Out:
#                                                               url  \
# breed
# Afador                      https://dogtime.com/dog-breeds/afador
# Affenhuahua            https://dogtime.com/dog-breeds/affenhuahua
# Affenpinscher        https://dogtime.com/dog-breeds/affenpinscher
# Afghan Hound          https://dogtime.com/dog-breeds/afghan-hound
# Airedale Terrier  https://dogtime.com/dog-breeds/airedale-terrier
#
#                   a_adaptability  a1_adapts_well_to_apartment_living  \
# breed
# Afador                         2                                   1
# Affenhuahua                    3                                   4
# Affenpinscher                  3                                   5
# Afghan Hound                   4                                   5
# Airedale Terrier               2                                   1
#
#                   a2_good_for_novice_owners  a3_sensitivity_level  \
# breed
# ...
