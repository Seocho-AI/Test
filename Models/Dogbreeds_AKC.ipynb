# %%
import pandas as pd
import numpy as np

# %%
breeds=pd.read_csv('dogbreeds-master/breeds.csv', index_col=0)
breeds_desc=pd.read_csv('akcdata-master/data/akc-data-latest.csv', index_col=0)

# %%
breeds_merge=breeds.merge(breeds_desc,left_on=breeds.index,right_on=breeds_desc.index, how='outer')

# %%
breeds_merge
# Out:
#                  key_0                                              url  \
# 0               Afador            https://dogtime.com/dog-breeds/afador
# 1          Affenhuahua       https://dogtime.com/dog-breeds/affenhuahua
# 2        Affenpinscher     https://dogtime.com/dog-breeds/affenpinscher
# 3         Afghan Hound      https://dogtime.com/dog-breeds/afghan-hound
# 4     Airedale Terrier  https://dogtime.com/dog-breeds/airedale-terrier
# ..                 ...                                              ...
# 414         Wetterhoun                                              NaN
# 415   Wire Fox Terrier                                              NaN
# 416  Wirehaired Vizsla                                              NaN
# 417     Working Kelpie                                              NaN
# 418     Yakutian Laika                                              NaN
#
#      a_adaptability  a1_adapts_well_to_apartment_living  \
# ...

# %%
breeds_merge.fillna(0)
# Out:
#                  key_0                                              url  \
# 0               Afador            https://dogtime.com/dog-breeds/afador
# 1          Affenhuahua       https://dogtime.com/dog-breeds/affenhuahua
# 2        Affenpinscher     https://dogtime.com/dog-breeds/affenpinscher
# 3         Afghan Hound      https://dogtime.com/dog-breeds/afghan-hound
# 4     Airedale Terrier  https://dogtime.com/dog-breeds/airedale-terrier
# ..                 ...                                              ...
# 414         Wetterhoun                                                0
# 415   Wire Fox Terrier                                                0
# 416  Wirehaired Vizsla                                                0
# 417     Working Kelpie                                                0
# 418     Yakutian Laika                                                0
#
#      a_adaptability  a1_adapts_well_to_apartment_living  \
# ...

# %%
breeds.columns
# Out:
# Index(['url', 'a_adaptability', 'a1_adapts_well_to_apartment_living',
#        'a2_good_for_novice_owners', 'a3_sensitivity_level',
#        'a4_tolerates_being_alone', 'a5_tolerates_cold_weather',
#        'a6_tolerates_hot_weather', 'b_all_around_friendliness',
#        'b1_affectionate_with_family', 'b2_incredibly_kid_friendly_dogs',
#        'b3_dog_friendly', 'b4_friendly_toward_strangers', 'c_health_grooming',
#        'c1_amount_of_shedding', 'c2_drooling_potential', 'c3_easy_to_groom',
#        'c4_general_health', 'c5_potential_for_weight_gain', 'c6_size',
#        'd_trainability', 'd1_easy_to_train', 'd2_intelligence',
#        'd3_potential_for_mouthiness', 'd4_prey_drive',
#        'd5_tendency_to_bark_or_howl', 'd6_wanderlust_potential',
#        'e_exercise_needs', 'e1_energy_level', 'e2_intensity',
#        'e3_exercise_needs', 'e4_potential_for_playfulness', 'breed_group',
#        'height', 'weight', 'life_span'],
#       dtype='object')

# %%
breeds.index
# Out:
# Index(['Afador', 'Affenhuahua', 'Affenpinscher', 'Afghan Hound',
#        'Airedale Terrier', 'Akbash', 'Akita', 'Alaskan Klee Kai',
#        'Alaskan Malamute', 'American Bulldog',
#        ...
#        'Welsh Springer Spaniel', 'Welsh Terrier',
#        'West Highland White Terrier', 'Westiepoo', 'Whippet', 'Whoodle',
#        'Wirehaired Pointing Griffon', 'Xoloitzcuintli', 'Yorkipoo',
#        'Yorkshire Terrier'],
#       dtype='object', name='breed', length=349)
